# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'F:\Data_analytics_internship_task\assi_2.csv',encoding='utf-8',parse_dates=True).set_index('SKU')
data.head()
# Out:
#       01-08-2019  02-08-2019  03-08-2019  04-08-2019  05-08-2019  06-08-2019  \
# SKU
# 2527        1551        1613        1613        1532        1517        1441
# 3042        2240        2330        2423        2350        2374        2398
# 3086         891         909         936         889         880         906
# 3155        1628        1628        1563        1532        1563        1563
# 3166         369         354         343         340         330         337
#
#       07-08-2019  08-08-2019  09-08-2019  10-08-2019  ...  22-07-2020  \
# SKU                                                   ...
# 2527        1383        1424        1381        1340  ...        1929
# 3042        2278        2210        2232        2277  ...        7096
# 3086         870         879         844         852  ...         829
# 3155        1532        1593        1513        1498  ...        1719
# 3166         350         343         340         340  ...         335
#
# ...

# %%
data.shape
# Out:
# (247, 366)

# %%
data_date_by=data.T
data_date_by.reset_index(inplace=True)
print(data_date_by.columns)
data_date_by
# Out:
# Index(['index', '2527', '3042', '3086', '3155', '3166', '8272', '9311',
#        '13159', '13160',
#        ...
#        'PPAM05126', 'PPAM05156', 'PPAM06156', 'PPAM07156', 'PPAM08156',
#        'PPAM11156', 'PSTM01257', 'PSTM01457', 'WIM5011B', 'WIM51234'],
#       dtype='object', name='SKU', length=248)
# SKU       index  2527  3042  3086  3155  3166  8272  9311  13159  13160  ...  \
# 0    01-08-2019  1551  2240   891  1628   369  1034   597     57     49  ...
# 1    02-08-2019  1613  2330   909  1628   354  1024   585     56     48  ...
# 2    03-08-2019  1613  2423   936  1563   343  1055   608     57     48  ...
# 3    04-08-2019  1532  2350   889  1532   340  1055   578     60     48  ...
# 4    05-08-2019  1517  2374   880  1563   330  1055   566     58     46  ...
# ..          ...   ...   ...   ...   ...   ...   ...   ...    ...    ...  ...
# 361  27-07-2020  1926  6606   772  2030   319   690   215     34     35  ...
# ...

# %%
data_date_by.columns
# Out:
# Index(['index', '2527', '3042', '3086', '3155', '3166', '8272', '9311',
#        '13159', '13160',
#        ...
#        'PPAM05126', 'PPAM05156', 'PPAM06156', 'PPAM07156', 'PPAM08156',
#        'PPAM11156', 'PSTM01257', 'PSTM01457', 'WIM5011B', 'WIM51234'],
#       dtype='object', name='SKU', length=248)

# %%
month=[]
for i in data_date_by['index']:
    month.append(i[3:])
data_date_by['month']=month
data_date_by
# Out:
# SKU       index  2527  3042  3086  3155  3166  8272  9311  13159  13160  ...  \
# 0    01-08-2019  1551  2240   891  1628   369  1034   597     57     49  ...
# 1    02-08-2019  1613  2330   909  1628   354  1024   585     56     48  ...
# 2    03-08-2019  1613  2423   936  1563   343  1055   608     57     48  ...
# 3    04-08-2019  1532  2350   889  1532   340  1055   578     60     48  ...
# 4    05-08-2019  1517  2374   880  1563   330  1055   566     58     46  ...
# ..          ...   ...   ...   ...   ...   ...   ...   ...    ...    ...  ...
# 361  27-07-2020  1926  6606   772  2030   319   690   215     34     35  ...
# 362  28-07-2020  1926  6804   811  2050   329   669   224     34     33  ...
# 363  29-07-2020  1849  6872   803  2132   336   649   228     33     34  ...
# 364  30-07-2020  1904  6872   763  2111   349   649   228     32     32  ...
# 365  31-07-2020  1828  7078   763  2027   352   630   228     31     33  ...
#
# ...

# %%
#What is the monthly & quaterly sales data by SKU
print(f"The monthly sales data by each SKU\n{'--'*40}")
monthly_sales=data_date_by.groupby(['month']).sum()
monthly_sales
# Out:
# The monthly sales data by each SKU
# --------------------------------------------------------------------------------
# SKU       2527    3042   3086   3155   3166   8272   9311  13159  13160  \
# month
# 01-2020  21853   79546  35670  75218  13990  16265   8532   2297   1248
# 02-2020  23170   78095  32029  61235  10517  14922   7193   2001   1154
# 03-2020  30956   92606  30827  72241   9587  18244   8971   1967    949
# 04-2020  38202  120947  25062  67543  12110  24042   9115   1800    845
# 05-2020  44347  135342  22231  57518   9838  33069  10741   1447   1062
# 06-2020  49341  157482  24184  53480   9076  22895   8341   1087   1261
# 07-2020  55826  196062  26153  54253  10182  20594   6834   1150   1168
# 08-2019  41702   69451  27412  46443  10720  31559  19045   1822   1485
# 09-2019  36880   62415  31687  41922  10306  35877  17797   1990   1753
# 10-2019  30582   71082  33122  45421  11966  35109  14797   1857   2045
# ...

# %%
#Which are the top 3 months in terms of overall sales
sum_by_month=monthly_sales.sum(axis=1,)
monthly_sales['sum_of_sales']=sum_by_month

top_3=monthly_sales.nlargest(3,'sum_of_sales')
print("The top 3 months based on the overall sales")
print('-'*69)
top_3['sum_of_sales']
# Out:
# The top 3 months based on the overall sales
# ---------------------------------------------------------------------
# month
# 03-2020    101172850
# 12-2019     97681350
# 01-2020     95850495
# Name: sum_of_sales, dtype: int64

# %%
#Which SKUs are outliers in terms sales in any month
scat=monthly_sales.T
scat.reset_index(inplace=True)
scat
# Out:
# month           SKU   01-2020   02-2020   03-2020   04-2020   05-2020  \
# 0              2527     21853     23170     30956     38202     44347
# 1              3042     79546     78095     92606    120947    135342
# 2              3086     35670     32029     30827     25062     22231
# 3              3155     75218     61235     72241     67543     57518
# 4              3166     13990     10517      9587     12110      9838
# ..              ...       ...       ...       ...       ...       ...
# 243       PSTM01257       742       803       725       704       797
# 244       PSTM01457       311       295       320       349       390
# 245        WIM5011B      1567      1430      1458       984       904
# 246        WIM51234        62        58        62        60        62
# 247    sum_of_sales  19170099  17973457  20234570  19103472  18555947
#
# month   06-2020   07-2020   08-2019   09-2019   10-2019   11-2019   12-2019
# ...

# %%
from matplotlib.pyplot import figure
figure(figsize=(10,35))
for x in scat.columns[1:]:
    plt.title(x)
    plt.scatter(x=scat[x],y=scat['SKU'])
    plt.xlabel(x)
    plt.ylabel('SKU')
    plt.show()

# %%
# fom this we can find the SKU 65001,65202,14119 is the outliers in almost all the moths
